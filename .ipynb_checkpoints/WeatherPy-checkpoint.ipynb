# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
weather_api_key
# Out:
# '1bce4c0df3b2293dfc66e783f97126f9'

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 595

# %%
#URL and Units
weather_url = "http://api.openweathermap.org/data/2.5/weather?"
units ="imperial"

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
query_url = weather_url + "appid=" + weather_api_key + "&q=" + city
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=1bce4c0df3b2293dfc66e783f97126f9&q=myitkyina'

# %%
example = cities[0]
test_url = query_url + example
test_response = requests.get (test_url).json()
from pprint import pprint
pprint(test_response)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 22.6783, 'lon': -3.9836},
#  'dt': 1614441833,
#  'id': 2450173,
#  'main': {'feels_like': 78.58,
#           'grnd_level': 993,
#           'humidity': 12,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 85.35,
#           'temp_max': 85.35,
#           'temp_min': 85.35},
#  'name': 'Taoudenni',
#  'sys': {'country': 'ML', 'sunrise': 1614407945, 'sunset': 1614449913},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 239, 'speed': 4.47}}

# %%
cities_df = pd.DataFrame({"City": cities})
cities_df. head()
# Out:
#            City
# 0     taoudenni
# 1  punta arenas
# 2       camargo
# 3          nome
# 4  constitucion

# %%
# begin with Variables 
city_name = []
c_country = []
date =[]
c_lat =[]
c_lon =[]
temp_max =[]
humid =[]
cloud =[]
wind =[]
i = 1


print (f"Beginning Data Retrival")
print ("-------------------------")

for city in cities:
    city=city
    query_url = weather_url + "appid=" + weather_api_key + "&q=" + city
    w_json =requests.get(query_url).json()
    
    try:      
        city_name.append(w_json ["name"])
        c_country.append(w_json["sys"]["country"])
        date.append(w_json["dt"])
        c_lat.append(w_json["coord"]["lat"])
        c_lon.append(w_json ["coord"]["lon"])
        temp_max.append(w_json["main"]["temp_max"])
        humid.append(w_json ["main"]["humidity"])
        cloud.append(w_json ["clouds"]["all"])
        wind.append(w_json ["wind"]["speed"])
        city_info = w_json["name"]
        print(f"Processing record {Record} | {city_info}")
        i+=1
    except (KeyError):
        print(f"City Not found, Skipping.....")
# Out:
# Beginning Data Retrival
# -------------------------
# Processing record 1 | Taoudenni
# Processing record 1 | Punta Arenas
# Processing record 1 | Camargo
# Processing record 1 | Nome
# Processing record 1 | Constitución
# Processing record 1 | Dikson
# Processing record 1 | Ust-Nera
# Processing record 1 | Norsup
# Processing record 1 | Ushuaia
# Processing record 1 | Tual
# Processing record 1 | Cape Town
# Processing record 1 | Fairbanks
# City Not found, Skipping.....
# Processing record 1 | Saldanha
# Processing record 1 | Kalininsk
# City Not found, Skipping.....
# Processing record 1 | Castro
# Processing record 1 | Lethem
# Processing record 1 | Longyearbyen
# Processing record 1 | Butaritari
# Processing record 1 | Xining
# Processing record 1 | Laas
# Processing record 1 | East London
# Processing record 1 | Hobart
# Processing record 1 | Hilo
# Processing record 1 | New Norfolk
# Processing record 1 | Sisimiut
# City Not found, Skipping.....
# Processing record 1 | Lata
# City Not found, Skipping.....
# Processing record 1 | Avarua
# Processing record 1 | São Gabriel da Cachoeira
# Processing record 1 | Touros
# Processing record 1 | Rikitea
# Processing record 1 | Qui Nhon
# Processing record 1 | Port Alfred
# Processing record 1 | Puerto Baquerizo Moreno
# Processing record 1 | Ulladulla
# Processing record 1 | Zhetysay
# Processing record 1 | Mazyr
# Processing record 1 | Lagoa
# Processing record 1 | Provideniya
# Processing record 1 | Arman'
# Processing record 1 | Jamestown
# Processing record 1 | Mataura
# Processing record 1 | Honningsvåg
# Processing record 1 | Swift Current
# Processing record 1 | Esperance
# City Not found, Skipping.....
# City Not found, Skipping.....
# Processing record 1 | Santa Quitéria
# Processing record 1 | Omboué
# Processing record 1 | Kapaa
# Processing record 1 | Torbay
# City Not found, Skipping.....
# Processing record 1 | Saskylakh
# Processing record 1 | Quatre Cocos
# Processing record 1 | Kedrovyy
# Processing record 1 | Busselton
# Processing record 1 | Tolbazy
# Processing record 1 | Vao
# Processing record 1 | Arraial do Cabo
# Processing record 1 | Chokurdakh
# Processing record 1 | Hermanus
# City Not found, Skipping.....
# Processing record 1 | Monchegorsk
# Processing record 1 | Yellowknife
# Processing record 1 | Half Moon Bay
# Processing record 1 | Albany
# Processing record 1 | Hay River
# Processing record 1 | Mehamn
# Processing record 1 | Puerto Ayora
# Processing record 1 | Caravelas
# Processing record 1 | Kiama
# Processing record 1 | Mogadishu
# Processing record 1 | Vaini
# Processing record 1 | Jasper
# City Not found, Skipping.....
# Processing record 1 | Maungatapere
# Processing record 1 | Meulaboh
# Processing record 1 | Ritto
# City Not found, Skipping.....
# Processing record 1 | Araçatuba
# Processing record 1 | Powell River
# Processing record 1 | Port Elizabeth
# Processing record 1 | Shingū
# Processing record 1 | Rongcheng
# Processing record 1 | Salalah
# Processing record 1 | Mastic Beach
# City Not found, Skipping.....
# Processing record 1 | Erzurum Province
# Processing record 1 | Ovsyanka
# Processing record 1 | Terrace
# Processing record 1 | Porto-Novo
# Processing record 1 | Dombås
# Processing record 1 | Zeya
# Processing record 1 | Cherskiy
# Processing record 1 | Esim
# Processing record 1 | Coquimbo
# Processing record 1 | Lebu
# Processing record 1 | Qaanaaq
# Processing record 1 | Khatanga
# Processing record 1 | Rawson
# Processing record 1 | São João da Barra
# Processing record 1 | Barkhan
# Processing record 1 | Poddor'ye
# Processing record 1 | Clyde River
# Processing record 1 | Vestmannaeyjar
# City Not found, Skipping.....
# Processing record 1 | Lavrentiya
# Processing record 1 | Hithadhoo
# City Not found, Skipping.....
# Processing record 1 | Saint-Augustin
# Processing record 1 | Hervey Bay
# City Not found, Skipping.....
# Processing record 1 | Rehoboth
# City Not found, Skipping.....
# Processing record 1 | Narsaq
# Processing record 1 | Gijang
# Processing record 1 | Portland
# Processing record 1 | Cross Lanes
# Processing record 1 | San Rafael
# Processing record 1 | Inverness
# Processing record 1 | Kahului
# Processing record 1 | Batagay
# Processing record 1 | Khandyga
# Processing record 1 | Amapá
# Processing record 1 | Mahébourg
# Processing record 1 | Necochea
# Processing record 1 | Port Blair
# Processing record 1 | Kerrville
# Processing record 1 | Balkhash
# Processing record 1 | Pacific Grove
# Processing record 1 | Srednekolymsk
# Processing record 1 | Potiskum
# Processing record 1 | Arica
# Processing record 1 | Majene
# Processing record 1 | Bredasdorp
# City Not found, Skipping.....
# Processing record 1 | Lüderitz
# Processing record 1 | Kumul
# Processing record 1 | Nikolskoye
# Processing record 1 | Nagato
# City Not found, Skipping.....
# Processing record 1 | Saint Paul Harbor
# Processing record 1 | Guerrero Negro
# Processing record 1 | Chicama
# Processing record 1 | Korsakov
# Processing record 1 | Barrow
# Processing record 1 | Fortuna
# Processing record 1 | San Luis
# Processing record 1 | Aklavik
# Processing record 1 | Kawalu
# Processing record 1 | Karratha
# Processing record 1 | Paamiut
# Processing record 1 | Saint-Philippe
# Processing record 1 | Bluff
# Processing record 1 | Chimbote
# Processing record 1 | Tura
# Processing record 1 | Okhotsk
# Processing record 1 | Russell
# Processing record 1 | Batī
# Processing record 1 | Qena
# Processing record 1 | Korla
# Processing record 1 | Itapirapuã
# Processing record 1 | Cabo San Lucas
# Processing record 1 | Nanortalik
# Processing record 1 | Vanimo
# Processing record 1 | Tavda
# Processing record 1 | Sur
# Processing record 1 | Ostrovnoy
# Processing record 1 | Hearst
# Processing record 1 | Isangel
# Processing record 1 | Ramotswa
# Processing record 1 | Hasaki
# Processing record 1 | Mar del Plata
# Processing record 1 | Pevek
# Processing record 1 | Taku
# Processing record 1 | Ribeira Grande
# Processing record 1 | Shahe
# City Not found, Skipping.....
# Processing record 1 | Zaysan
# Processing record 1 | Nālūt
# Processing record 1 | Kushiro
# Processing record 1 | Dingle
# Processing record 1 | Launceston
# Processing record 1 | Saint George
# Processing record 1 | Hurricane
# Processing record 1 | Sibolga
# Processing record 1 | Kastamonu Province
# Processing record 1 | Chebsara
# Processing record 1 | Kamenka
# Processing record 1 | Rocha
# Processing record 1 | Algiers
# Processing record 1 | Komatipoort
# Processing record 1 | Atuona
# Processing record 1 | Tiksi
# Processing record 1 | Cayenne
# Processing record 1 | Fort Nelson
# Processing record 1 | Tuktoyaktuk
# Processing record 1 | Kysyl-Syr
# Processing record 1 | Kasongo-Lunda
# Processing record 1 | Trnava
# Processing record 1 | Palmer
# Processing record 1 | Pailón
# Processing record 1 | Washougal
# Processing record 1 | Kavaratti
# Processing record 1 | Bambanglipuro
# Processing record 1 | Thinadhoo
# Processing record 1 | Cardoso
# City Not found, Skipping.....
# Processing record 1 | Rio Grande
# City Not found, Skipping.....
# Processing record 1 | Tsimlyansk
# Processing record 1 | Paciran
# City Not found, Skipping.....
# Processing record 1 | Elko
# Processing record 1 | Galiākot
# Processing record 1 | Vredendal
# Processing record 1 | Asău
# Processing record 1 | Luís Correia
# Processing record 1 | Bukachacha
# Processing record 1 | Vila
# Processing record 1 | Grand Gaube
# Processing record 1 | Thompson
# Processing record 1 | San Patricio
# Processing record 1 | Saint-Joseph
# Processing record 1 | Road Town
# Processing record 1 | Siljan
# Processing record 1 | George Town
# Processing record 1 | Gizo Government Station
# Processing record 1 | Kazanskaya
# Processing record 1 | College
# Processing record 1 | Upernavik
# Processing record 1 | São Filipe
# Processing record 1 | Bethel
# Processing record 1 | Pisco
# City Not found, Skipping.....
# Processing record 1 | Husavik
# Processing record 1 | Sinnamary
# Processing record 1 | Itanagar
# Processing record 1 | Turukhansk
# Processing record 1 | Airai
# Processing record 1 | Bahía Honda
# Processing record 1 | Ambilobe
# Processing record 1 | Emerald
# Processing record 1 | Kirakira
# Processing record 1 | Normandin
# Processing record 1 | Santa Marta
# Processing record 1 | Sept-Îles
# Processing record 1 | Kruisfontein
# Processing record 1 | Kinel’-Cherkassy
# Processing record 1 | Lahaina
# Processing record 1 | Uruaçu
# Processing record 1 | Tuatapere
# Processing record 1 | Tambovka
# Processing record 1 | Vilyuysk
# Processing record 1 | Dunedin
# City Not found, Skipping.....
# Processing record 1 | Siocon
# Processing record 1 | Bolobo
# Processing record 1 | Ponta do Sol
# Processing record 1 | Redcliffe
# Processing record 1 | Rome
# Processing record 1 | Tuy Hoa
# Processing record 1 | Severo-Kuril'sk
# Processing record 1 | Rock Springs
# Processing record 1 | Araouane
# Processing record 1 | Faanui
# Processing record 1 | Kaitangata
# Processing record 1 | Aswān
# Processing record 1 | Likasi
# Processing record 1 | Oussouye
# Processing record 1 | Tasiilaq
# City Not found, Skipping.....
# Processing record 1 | Vila Franca do Campo
# Processing record 1 | Lompoc
# City Not found, Skipping.....
# Processing record 1 | La Rioja
# Processing record 1 | Sol'-Iletsk
# Processing record 1 | Lagoa da Prata
# Processing record 1 | Collie
# Processing record 1 | Ozernovskiy
# City Not found, Skipping.....
# Processing record 1 | Sola
# Processing record 1 | Chui
# Processing record 1 | Daura
# Processing record 1 | Hong Kong
# Processing record 1 | Luganville
# Processing record 1 | Talnakh
# Processing record 1 | Kavieng
# Processing record 1 | Novobirilyussy
# Processing record 1 | Nishihara
# Processing record 1 | Oddur
# Processing record 1 | East Cleveland
# Processing record 1 | General Roca
# Processing record 1 | Beyneu
# City Not found, Skipping.....
# Processing record 1 | Bengkulu
# Processing record 1 | Viedma
# Processing record 1 | Jūrmala
# Processing record 1 | Mabaruma
# Processing record 1 | Vallenar
# Processing record 1 | Zhigansk
# City Not found, Skipping.....
# Processing record 1 | Ballina
# Processing record 1 | Strängnäs
# Processing record 1 | Havøysund
# Processing record 1 | Santa Vitória do Palmar
# City Not found, Skipping.....
# Processing record 1 | Beya
# Processing record 1 | Margherita
# Processing record 1 | Sitka
# Processing record 1 | Numan
# Processing record 1 | Muros
# Processing record 1 | Minuri
# Processing record 1 | Zatoka
# Processing record 1 | Los Llanos de Aridane
# Processing record 1 | Nampula
# Processing record 1 | São Paulo de Olivença
# Processing record 1 | Klaksvík
# Processing record 1 | Visby
# Processing record 1 | Mahon
# Processing record 1 | Feldkirchen
# Processing record 1 | Bratsk
# Processing record 1 | Alta Floresta
# Processing record 1 | Naze
# Processing record 1 | Tikhvin
# Processing record 1 | Margate
# City Not found, Skipping.....
# Processing record 1 | Tupik
# Processing record 1 | Ust-Tsilma
# Processing record 1 | Anadyr
# City Not found, Skipping.....
# Processing record 1 | Buala
# Processing record 1 | Gambo
# Processing record 1 | Marsala
# Processing record 1 | Micoud
# Processing record 1 | Lavaca
# Processing record 1 | Guangyuan
# Processing record 1 | Kirs
# Processing record 1 | Yichang
# Processing record 1 | Iqaluit
# Processing record 1 | Witu
# Processing record 1 | Manta
# City Not found, Skipping.....
# Processing record 1 | Ulaangom
# Processing record 1 | Yulara
# Processing record 1 | Avilés
# Processing record 1 | Sambava
# Processing record 1 | Paris
# City Not found, Skipping.....
# Processing record 1 | Murgab
# Processing record 1 | Lima Duarte
# Processing record 1 | Broome
# City Not found, Skipping.....
# Processing record 1 | Staryy Nadym
# Processing record 1 | Grindavik
# Processing record 1 | Saint-Pierre
# Processing record 1 | Victoria Point
# Processing record 1 | Salinas
# Processing record 1 | Belle Fourche
# Processing record 1 | Kodinsk
# Processing record 1 | Navolato
# Processing record 1 | Turangi
# Processing record 1 | Belaya Gora
# Processing record 1 | Te Anau
# Processing record 1 | Bad Windsheim
# Processing record 1 | Nizwá
# Processing record 1 | Serowe
# Processing record 1 | Arroyo de la Encomienda
# Processing record 1 | La Seyne-sur-Mer
# Processing record 1 | São Félix do Xingu
# Processing record 1 | Praia da Vitória
# Processing record 1 | Camabatela
# Processing record 1 | Acajutla
# Processing record 1 | Chimichagua
# Processing record 1 | Kashgar
# Processing record 1 | Sidi Ali
# Processing record 1 | Chihuahua
# Processing record 1 | Cabra
# Processing record 1 | Daru
# Processing record 1 | Coyhaique
# Processing record 1 | Isiro
# Processing record 1 | Aranos
# Processing record 1 | Salekhard
# Processing record 1 | Nizhniy Tsasuchey
# Processing record 1 | Calvinia
# Processing record 1 | Marabu
# Processing record 1 | Egvekinot
# Processing record 1 | Marijampolė
# Processing record 1 | Balaipungut
# Processing record 1 | Poum
# Processing record 1 | Río Gallegos
# Processing record 1 | Timrå
# Processing record 1 | Bambous Virieux
# Processing record 1 | Codrington
# Processing record 1 | Padang
# Processing record 1 | Alofi
# Processing record 1 | Mtinko
# Processing record 1 | The Valley
# Processing record 1 | Aleksandrovskoye
# Processing record 1 | Manche
# Processing record 1 | Moerai
# Processing record 1 | Esmeraldas
# Processing record 1 | Kropotkin
# Processing record 1 | Auki
# Processing record 1 | Krasnosel'kup
# Processing record 1 | Menongue
# Processing record 1 | Haines Junction
# Processing record 1 | San Cristobal
# Processing record 1 | Kuala Terengganu
# Processing record 1 | Moose Factory
# Processing record 1 | Somerset
# Processing record 1 | Abong Mbang
# Processing record 1 | Inuvik
# Processing record 1 | Wanaka
# Processing record 1 | Kūhdasht
# Processing record 1 | Tame
# Processing record 1 | Antofagasta
# Processing record 1 | Palauig
# Processing record 1 | Hecelchakán
# Processing record 1 | Mackay
# Processing record 1 | Leningradskiy
# Processing record 1 | Laguna
# Processing record 1 | Benguela
# Processing record 1 | Aykhal
# Processing record 1 | Katobu
# Processing record 1 | Skagen
# Processing record 1 | Ossora
# Processing record 1 | Hualmay
# Processing record 1 | Grand Forks
# Processing record 1 | Flinders
# Processing record 1 | Jalu
# Processing record 1 | Gerāsh
# Processing record 1 | Cidreira
# Processing record 1 | Jizan
# Processing record 1 | Lubumbashi
# Processing record 1 | Mount Isa
# Processing record 1 | Nabire
# Processing record 1 | Tiarei
# Processing record 1 | Giroc
# City Not found, Skipping.....
# Processing record 1 | Pontianak
# Processing record 1 | Toamasina
# Processing record 1 | Kazanka
# Processing record 1 | Kuching
# Processing record 1 | Tsiroanomandidy
# Processing record 1 | Prince Rupert
# Processing record 1 | Umeå
# Processing record 1 | Moroto
# Processing record 1 | Wanning
# Processing record 1 | Qaqortoq
# Processing record 1 | Āgaro
# Processing record 1 | Cocachacra
# Processing record 1 | Lorengau
# Processing record 1 | Galanta
# Processing record 1 | Norman Wells
# Processing record 1 | Eidsvåg
# Processing record 1 | Lago da Pedra
# Processing record 1 | Kiryat Gat
# Processing record 1 | Sadova
# Processing record 1 | Departamento de Maldonado
# Processing record 1 | Olafsvik
# Processing record 1 | Madison
# Processing record 1 | Terrenate
# Processing record 1 | Eyl
# Processing record 1 | Maniitsoq
# Processing record 1 | Huarmey
# Processing record 1 | Acapulco de Juárez
# Processing record 1 | Ambulu
# Processing record 1 | Strezhevoy
# Processing record 1 | Pierre
# Processing record 1 | Ila
# Processing record 1 | Kungurtug
# Processing record 1 | Westport
# Processing record 1 | Namatanai
# Processing record 1 | Shimoda
# Processing record 1 | Ugoofaaru
# City Not found, Skipping.....
# Processing record 1 | Tabou
# Processing record 1 | High Level
# Processing record 1 | Nivala
# Processing record 1 | Garoowe
# Processing record 1 | Beira
# Processing record 1 | Colesberg
# Processing record 1 | Anori
# Processing record 1 | Pervomays'k
# Processing record 1 | Mbour
# Processing record 1 | Takoradze
# City Not found, Skipping.....
# Processing record 1 | Vostok
# Processing record 1 | Beloha
# Processing record 1 | Nortelândia
# Processing record 1 | Grandview
# Processing record 1 | Jiuquan
# Processing record 1 | Panacan
# Processing record 1 | Kununurra
# Processing record 1 | Grand-Lahou
# Processing record 1 | Vardø
# Processing record 1 | Akbarpur
# Processing record 1 | Coahuayana Viejo
# Processing record 1 | Srandakan
# Processing record 1 | Yumen
# Processing record 1 | Kalat
# Processing record 1 | Verkhnedneprovskiy
# Processing record 1 | Malia
# Processing record 1 | Wenling
# Processing record 1 | Balakhta
# Processing record 1 | Ambon City
# Processing record 1 | Noumea
# Processing record 1 | Moultrie
# Processing record 1 | Hambantota
# Processing record 1 | Mēga
# Processing record 1 | Grand Island
# Processing record 1 | Tautira
# Processing record 1 | Assiut
# Processing record 1 | Gao
# Processing record 1 | Huron
# Processing record 1 | Salinópolis
# Processing record 1 | Port Lincoln
# Processing record 1 | Buraidah
# Processing record 1 | Schroeder
# Processing record 1 | Yazman
# Processing record 1 | Ucluelet
# Processing record 1 | Haifa
# Processing record 1 | Tumbes
# Processing record 1 | Portage
# Processing record 1 | Barcelos
# Processing record 1 | Penzance
# Processing record 1 | Matara
# Processing record 1 | Makakilo City
# Processing record 1 | Bandarbeyla
# Processing record 1 | Alyangula
# City Not found, Skipping.....
# Processing record 1 | Muli
# Processing record 1 | Yaguajay
# Processing record 1 | Brawley
# City Not found, Skipping.....
# Processing record 1 | Sittwe
# Processing record 1 | Along
# City Not found, Skipping.....
# Processing record 1 | Nevel'sk
# Processing record 1 | Ancud
# Processing record 1 | Sosnovka
# Processing record 1 | Santiago del Estero
# Processing record 1 | Hondomachi-hondo
# Processing record 1 | Alice
# Processing record 1 | Rožňava
# Processing record 1 | Carnarvon
# Processing record 1 | Ekhabi
# Processing record 1 | Deep River
# Processing record 1 | Storsteinnes
# Processing record 1 | Tarko-Sale
# City Not found, Skipping.....
# Processing record 1 | Ermelo
# Processing record 1 | Matamoros
# Processing record 1 | Hendersonville
# Processing record 1 | Pangani
# Processing record 1 | Pedasí
# Processing record 1 | Banda Aceh
# Processing record 1 | Balikpapan
# Processing record 1 | Levelland
# Processing record 1 | Burnie
# Processing record 1 | Havelock
# Processing record 1 | Pasni
# Processing record 1 | Nouadhibou
# Processing record 1 | Cunha
# Processing record 1 | Souillac
# Processing record 1 | Baykit
# Processing record 1 | Teya
# City Not found, Skipping.....
# Processing record 1 | Nuevitas
# Processing record 1 | Gubkinskiy
# Processing record 1 | Mount Gambier
# Processing record 1 | Bermejillo
# Processing record 1 | Urengoy
# Processing record 1 | Port-Gentil
# Processing record 1 | Geraldton
# Processing record 1 | Chu
# Processing record 1 | Mae Hong Son
# Processing record 1 | Pascagoula
# Processing record 1 | Tadine
# Processing record 1 | Nanning
# Processing record 1 | Annau
# Processing record 1 | Nola
# Processing record 1 | Beckley
# Processing record 1 | Boone
# Processing record 1 | Las Lomas
# Processing record 1 | ‘Āhuimanu
# Processing record 1 | Valparaíso
# Processing record 1 | Verkhniy Baskunchak
# Processing record 1 | Petropavlovsk-Kamchatskiy
# Processing record 1 | Pontal do Paraná
# Processing record 1 | Myitkyina

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert to Dataframe
weather_d= {'City Name': city_name,'Country': c_country,'Cloudiness': cloud,'Lat':c_lat,'Long':c_lon,'Humidity':humid,'Windspeed':wind,'Temperature':temp_max}
weather_df =pd.DataFrame(weather_d, columns=('City Name','Country','Cloudiness','Lat','Long','Humidity', 'Windspeed','Temperature'))
weather_df.head()
# Out:
#       City Name Country  Cloudiness      Lat      Long  Humidity  Windspeed  \
# 0     Taoudenni      ML           0  22.6783   -3.9836        17       1.16
# 1  Punta Arenas      CL           0 -53.1500  -70.9167        35       7.20
# 2       Camargo      MX         100  27.6667 -105.1667        16       7.13
# 3          Nome      US           1  64.5011 -165.4064        70       2.69
# 4  Constitución      CL           2 -35.3333  -72.4167        49       6.67
#
#    Temperature
# 0       297.08
# 1       296.15
# 2       298.70
# 3       249.15
# 4       295.24

# %%
weather_df.to_csv(output_data_file)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
